# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import sklearn

print("Python:", sys.version.split()[0])
print("Executable:", sys.executable)
print("NumPy:", np.__version__)
print("pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# Python: 3.12.14
# Executable: c:\Users\Vasil\miniconda3\envs\ml-foundations\python.exe
# NumPy: 2.5.2
# pandas: 3.0.5
# Matplotlib: 3.11.2
# scikit-learn: 1.9.1
